# %% [markdown]
# # Lists, Dicts & Read
#
# The goal for this homework is to see the relevant journalistic uses for what we covered in class.
#
# 1. Creating lists
# 2. Building dictionaries
# 3. Ingest a dataset

# %% [markdown]
# ## Creating Lists
#
# You've <a href="https://apps.health.ny.gov/pubdoh/professionals/doctors/conduct/factions/AllRecordsAction.action?">scraped thousands of documents</a> that contain disciplinary actions against doctors in New York state. You compile key words and phrases that will target certain types of violations. These include:
#
# - improper touching
# - self-medication
# - self-prescribing
# - opioid addiction
# - harassment
# - coercion
# - sexual harrassment
# - sex
# - sexual favor
# - abuse of trust
# - opioid prescriptions in return for sex
#
# Create a list called ```search_terms``` that holds the search terms above.

# %%
## create the list here (create more cells if necessary)
search_terms = ["improper_touching", "self-medication", "self-prescribing", "opioid_addiction", "harassment", "coercion", "sexual_harassment", "sex", "sexual_favor", "abuse_of_trust", "opioid_prescriptions_in_return_for_sex"]

# %%
print(search_terms)
# Out:
# ['improper_touching', 'self-medication', 'self-prescribing', 'opioid_addiction', 'harassment', 'coercion', 'sexual_harassment', 'sex', 'sexual_favor', 'abuse_of_trust', 'opioid_prescriptions_in_return_for_sex']

# %%
type(search_terms)
# Out:
# list

# %%
## What type of a data object is ```search_term```
type(search_terms)
# Out:
# list

# %%
## It's a list!

# %% [markdown]
# ## How long is this list?

# %%
## It's 11 items long or 11 rows in a spreadsheet. Is that the question?

# %% [markdown]
# ### Building dictionaries
#
# Create a list of dictionaries called "donations" using the content from the image below:
#
# <img src="https://sandeepmj.github.io/image-host/donors.png">
#
# ## If you want to copy and paste the content, click <a href="https://docs.google.com/spreadsheets/d/17JBUMJpAiMz5WavglaE3HLHijRxHHJUd/edit?usp=sharing&ouid=107646296031550187966&rtpof=true&sd=true" target="blank">here</a> to download the Excel file.
#
#
# You may copy and paste the contents of each cell in the XLSX file, but type out all the code required to build the list of dictionaries.

# %%
## code it here
## example car_2 = { "vin": 5237, "brand":"Honda", "body": "Sedan", "model": "Accord", "trim": "cloth", "cost": 40_000, "on_sale": True, "type":"Gas"}

donations_1 = {"year": 2017, "donor": "David_H_Koch_Charitable_Foundation", "grantee": "City_Center_For_Music_And_Drama", "amount": 15_000_000}
donations_2 = {"year": 2013, "donor": "Bradley_Impact_Fund_Inc", "grantee":  "Young_Americas_Foundation", "amount": 11_000}
donations_3 = {"year": 2016, "donor": "Mercer_Family_Foundation", "grantee": "The_Becket_Fund", "amount": 250_000}
donations_4 = {"year": 2012, "donor": "Charles_Koch_Foundation", "grantee": "The_Phillips_Foundation", "amount": 25_000}
donations_5 = {"year": 2017, "donor": "Barbara_And_Barre_Seid_Foundation", "grantee": "Boys_Scouts_of_America", "amount": 2_634_600}

## Question: Is there a better way to label dicts?

# %%
## print the list of dictionaries
##example: cars_list = [car_1, car_2]

donations_list = [donations_1, donations_2, donations_3, donations_4, donations_5]
print(donations_list)
# Out:
# [{'year': 2017, 'donor': 'David_H_Koch_Charitable_Foundation', 'grantee': 'City_Center_For_Music_And_Drama', 'amount': 15000000}, {'year': 2013, 'donor': 'Bradley_Impact_Fund_Inc', 'grantee': 'Young_Americas_Foundation', 'amount': 11000}, {'year': 2016, 'donor': 'Mercer_Family_Foundation', 'grantee': 'The_Becket_Fund', 'amount': 250000}, {'year': 2012, 'donor': 'Charles_Koch_Foundation', 'grantee': 'The_Phillips_Foundation', 'amount': 25000}, {'year': 2017, 'donor': 'Barbara_And_Barre_Seid_Foundation', 'grantee': 'Boys_Scouts_of_America', 'amount': 2634600}]

# %%
## call donations

donations_list
# Out:
# [{'year': 2017,
#   'donor': 'David_H_Koch_Charitable_Foundation',
#   'grantee': 'City_Center_For_Music_And_Drama',
#   'amount': 15000000},
#  {'year': 2013,
#   'donor': 'Bradley_Impact_Fund_Inc',
#   'grantee': 'Young_Americas_Foundation',
#   'amount': 11000},
#  {'year': 2016,
#   'donor': 'Mercer_Family_Foundation',
#   'grantee': 'The_Becket_Fund',
#   'amount': 250000},
#  {'year': 2012,
#   'donor': 'Charles_Koch_Foundation',
#   'grantee': 'The_Phillips_Foundation',
#   'amount': 25000},
#  {'year': 2017,
#   'donor': 'Barbara_And_Barre_Seid_Foundation',
#   'grantee': 'Boys_Scouts_of_America',
#   'amount': 2634600}]

# %% [markdown]
# #### Notice the difference between ```print()``` and ```calling```?

# %%
## Print just lists everything while calling keeps it organized in dicts. Less data clean up, I think.

# %%
## How many items are in this list?
## Don't just manually count them.
## There will come a time when you will have thousands of items!

# %%
## I consulted Claude and I like the analogy of books & shelves.
## Think of this like a shelf. Each {} is one book. The whole shelf [] holds all the books.

##Step 1: Understand what you have
##The outer [ ] is the list — it's the shelf
##Each inner { } is a dict — it's one book
##So: "How many books are on the shelf?" = "How many dicts are in the list?"

len(donations_list)
# Out:
# 5

# %%
##LP note to self: The error was when adjusted and didn't re-run (shift + enter) an earlier cell

# %% [markdown]
# ## Reading data
#
# Download this [sample dataset](https://drive.google.com/file/d/18bW5naPyYbm--nk1meOvTPBNg8gYLk7T/view?usp=sharing) and read it into this notebook.
#
# **Remember that you have to import the appropriate library before you can read the dataset into this notebook.**

# %%
## code here/ create cells as necessary.

import pandas as pd

# %%
## simply read the csv file when data file is at the same level (same folder)
pd.read_csv("summons_sample.csv")
# Out:
#     SUMMONS_KEY SUMMONS_DATE              OFFENSE_DESCRIPTION  \
# 0     286197370   05/01/2024     ALCOHOLIC BEVERAGE IN PUBLIC
# 1     278254074   11/29/2023                 RECKLESS DRIVING
# 2     253581920   11/03/2022     ALCOHOLIC BEVERAGE IN PUBLIC
# 3     262113325   01/18/2023                          SMOKING
# 4     272793060   08/13/2023     ALCOHOLIC BEVERAGE IN PUBLIC
# ..          ...          ...                              ...
# 95    248384568   07/22/2022    FEDERAL MOTOR VEH. SAFETY REG
# 96    260567194   12/27/2022  UNLAWFUL POSSESSION OF CANNABIS
# 97    266775475   04/16/2023              URINATING IN PUBLIC
# 98    244900926   05/11/2022     ALCOHOLIC BEVERAGE IN PUBLIC
# 99    283895181   03/17/2024               DISORDERLY CONDUCT
#
#    LAW_SECTION_NUMBER      LAW_DESCRIPTION SUMMONS_CATEGORY_TYPE AGE_GROUP  \
# 0          10-125(2B)               (null)                (null)     25-44
# ...

# %% [markdown]
# # ABSOLUTELY NAILED IT
